# %% [markdown]
# # Markdown Syntax

# %% [markdown]
# ## 1.글씨크기
#
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6
# ####### Header 7

# %% [markdown]
# <h1> Header 1</h1>
# <h2> Header 2</h2>
# <h3> Header 3</h3>
# <h4> Header 4</h4>
# <h5> Header 5</h5>
# <h6> Header 6</h6>
# <h7> Header 7</h7>

# %% [markdown]
# ## 2. 텍스트와 강조
# 일반 텍스트
# 새로운 단락을 시작하려면 단락의 마지막 부분에 커서를 두고 ENTER를 두 번 누른다.
# 새로운 문장을 시작하려면 문장의 마지막 부분에 커서를 두고 스페이스를 두 번 이상 누른 후 ENTER를 한 번 누른다.
#
# *기울인 글씨* and _기울인 글씨_
#
# **굵은 글씨** and __굵은 글씨__
#
# ~~취소선~~

# %% [markdown]
# ## 3.목록
#
# * 순서없는 목록
# * 항목2
#  + 하위 항목 1
#  + 하위 항목 2
#
#
#  1. 순서있는 목록
#  2. 항목2
#   + 하위 항목 1
#   + 하위 항목 2

# %% [markdown]
# ## 4.코드
# 인라인코드 : `print()`
# 블록코드(언어지정X)
# ```
# for i in range(10):
#     print(10)
# ```
# 블록코드(언어지정O)
# ```python
# for i in range(10):
#     print(10)
# ```

# %% [markdown]
# ## 5.링크와 이미지
# `[텍스트] (url)`
# [파이썬 홈페이지](https://www.python.org/)
#
#
#  `![캡션](path of image url)`
# [Jupyter]![image.png](attachment:image.png)

# %% [markdown]
# ## 6.인용
#
# > 인용 블록
# >> 인용 블록

# %% [markdown]
# ## 7.표와 나눔선
# 표 제목 | 두번째 제목
# --------|------------
# 표칸    | 칸2
# 칸3     | 칸4
#
# 나눔선:
#
# ***
# ---

# %% [markdown]
# ## 8.수식
# 인라인 수식 : $y = ax$
# 블록수식 :
# $$ z = y + b $$
